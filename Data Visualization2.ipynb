# %%
#pip install scikit-learn

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.preprocessing import Normalizer

# %%
import pandas as pd

# %%
import numpy as np

# %%
normal_df=pd.DataFrame({'x':np.random.randint(-100,100,1000),
                        'y':np.random.randint(-80,80,1000),
                        'z':np.random.randint(-150,150,1000)})

# %%
normal_df
# Out:
#       x   y    z
# 0    41  12  -69
# 1    36 -26  -70
# 2   -87  69   59
# 3   -53  51   57
# 4    95 -73  -99
# ..   ..  ..  ...
# 995  -7  46   32
# 996 -64   5 -136
# 997  33  71  -57
# 998  25  49  -66
# 999 -16  59  -29
#
# [1000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
ax=plt.axes(projection='3d')
ax.scatter3D(normal_df.x,normal_df.y,normal_df.z)
plt.figure()

# %%
norm=Normalizer()

# %%
norm_df=norm.fit_transform(normal_df)

# %%
norm_df
# Out:
# array([[ 0.50521123,  0.1478667 , -0.85023353],
#        [ 0.4342711 , -0.31364024, -0.84441602],
#        [-0.69189403,  0.54874354,  0.46921549],
#        ...,
#        [ 0.34074985,  0.73312846, -0.58856792],
#        [ 0.2909732 ,  0.57030747, -0.76816924],
#        [-0.23647329,  0.87199525, -0.42860783]])

# %%
norm_df=pd.DataFrame(normal_df,columns=['x','y','z'])

# %%
ax=plt.axes(projection='3d')
ax.scatter3D(norm_df.x,norm_df.y,norm_df.z)
plt.figure()

# %%
data={'First Score':[100,90,np.nan,95],
      'Second Score':[98,90,59,np.nan],
      'Third Score':[80,99,88,95]}

# %%
var=pd.DataFrame(data)

# %%
var
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          98.0           80
# 1         90.0          90.0           99
# 2          NaN          59.0           88
# 3         95.0           NaN           95

# %%
var.isnull()
var.isnull().sum()
# Out:
# First Score     1
# Second Score    1
# Third Score     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
imputer.fit(var)
imputer.transform(var)
# Out:
# array([[100.        ,  98.        ,  80.        ],
#        [ 90.        ,  90.        ,  99.        ],
#        [ 95.        ,  59.        ,  88.        ],
#        [ 95.        ,  82.33333333,  95.        ]])
