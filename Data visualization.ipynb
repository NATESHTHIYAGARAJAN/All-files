# %%
# pip install matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Heroes=['Thor','Hulk','Wanda','Doctor Strange','Ironman']
percentage=[20,20,20,20,20]

# %%
plt.scatter(Heroes,percentage)

# %%
plt.plot(Heroes,percentage,linestyle='dashdot')

# %%
plt.plot(Heroes,percentage,linestyle='dotted')

# %%
plt.plot(Heroes,percentage,linestyle='solid')

# %%
plt.bar(Heroes,percentage)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.pie(percentage,labels=Heroes)
# Out:
# ([<matplotlib.patches.Wedge at 0x19b9dc1ec20>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'Thor'),
#   Text(-0.3399187231970732, 1.046162158377023, 'Hulk'),
#   Text(-1.0999999999999988, -5.149471622296949e-08, 'Wanda'),
#   Text(-0.33991862524830174, -1.0461621902025062, 'Doctor Strange'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Ironman')])

# %%
import numpy as np

# %%
time=np.arange(0,10,0.05)
time
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  , 1.05,
#        1.1 , 1.15, 1.2 , 1.25, 1.3 , 1.35, 1.4 , 1.45, 1.5 , 1.55, 1.6 ,
#        1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 , 1.95, 2.  , 2.05, 2.1 , 2.15,
#        2.2 , 2.25, 2.3 , 2.35, 2.4 , 2.45, 2.5 , 2.55, 2.6 , 2.65, 2.7 ,
#        2.75, 2.8 , 2.85, 2.9 , 2.95, 3.  , 3.05, 3.1 , 3.15, 3.2 , 3.25,
#        3.3 , 3.35, 3.4 , 3.45, 3.5 , 3.55, 3.6 , 3.65, 3.7 , 3.75, 3.8 ,
#        3.85, 3.9 , 3.95, 4.  , 4.05, 4.1 , 4.15, 4.2 , 4.25, 4.3 , 4.35,
#        4.4 , 4.45, 4.5 , 4.55, 4.6 , 4.65, 4.7 , 4.75, 4.8 , 4.85, 4.9 ,
#        4.95, 5.  , 5.05, 5.1 , 5.15, 5.2 , 5.25, 5.3 , 5.35, 5.4 , 5.45,
#        5.5 , 5.55, 5.6 , 5.65, 5.7 , 5.75, 5.8 , 5.85, 5.9 , 5.95, 6.  ,
#        6.05, 6.1 , 6.15, 6.2 , 6.25, 6.3 , 6.35, 6.4 , 6.45, 6.5 , 6.55,
#        6.6 , 6.65, 6.7 , 6.75, 6.8 , 6.85, 6.9 , 6.95, 7.  , 7.05, 7.1 ,
# ...

# %%
amplitude=np.sin(time)
amplitude
# Out:
# array([ 0.        ,  0.04997917,  0.09983342,  0.14943813,  0.19866933,
#         0.24740396,  0.29552021,  0.34289781,  0.38941834,  0.43496553,
#         0.47942554,  0.52268723,  0.56464247,  0.60518641,  0.64421769,
#         0.68163876,  0.71735609,  0.75128041,  0.78332691,  0.8134155 ,
#         0.84147098,  0.86742323,  0.89120736,  0.91276394,  0.93203909,
#         0.94898462,  0.96355819,  0.97572336,  0.98544973,  0.99271299,
#         0.99749499,  0.99978376,  0.9995736 ,  0.99686503,  0.99166481,
#         0.98398595,  0.97384763,  0.9612752 ,  0.94630009,  0.92895972,
#         0.90929743,  0.88736237,  0.86320937,  0.83689879,  0.8084964 ,
#         0.7780732 ,  0.74570521,  0.71147335,  0.67546318,  0.6377647 ,
#         0.59847214,  0.55768372,  0.51550137,  0.47203054,  0.42737988,
#         0.38166099,  0.33498815,  0.28747801,  0.23924933,  0.19042265,
#         0.14112001,  0.09146464,  0.04158066, -0.00840725, -0.05837414,
# ...

# %%
plt.plot(time,amplitude)

# %%
#pip install seaborn

# %%
import numpy as np

# %%
import seaborn as sbn

# %%
sbn.set(style='darkgrid')

# %%
random=np.random.randn(100)

# %%
random
# Out:
# array([ 0.50387528,  1.0299023 , -0.36053371,  0.3898479 , -0.45293945,
#        -0.74375122, -1.28687351, -1.27037065, -0.43300477,  0.95491881,
#        -0.50792051,  1.28644966,  0.43574288, -0.03017175,  0.91050629,
#         0.16942722, -0.50664229,  1.64965721, -0.94302559, -0.30012108,
#         0.01142465,  2.0226795 ,  1.82310069,  0.81474039,  0.32944995,
#        -0.36595963, -2.63529531, -2.88184418, -0.35291773,  0.33427909,
#         0.110102  ,  0.44084035,  0.37372545, -0.94463298,  0.29507811,
#         0.89862276,  2.32880259,  0.63063652, -0.86768691,  0.96630271,
#         0.2890687 ,  0.48860177, -0.71180735, -1.98337403, -0.68353814,
#         0.82161734,  0.01907425, -0.50502116, -0.11660142,  0.96439068,
#         0.02504274,  0.19185735,  0.98869108, -2.14790483,  0.63353846,
#        -0.68390354, -0.16236809,  0.09401308, -0.05945887, -0.31831509,
#         0.73318572, -0.14378372, -1.14803522, -1.47867446,  1.52268114,
# ...

# %%
sbn.displot(random)

# %%
sbn.distplot(random)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1096\1777461163.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(random)
# <AxesSubplot: ylabel='Density'>

# %%
sbn.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tip=sbn.load_dataset('titanic')

# %%
tip
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tip=sbn.load_dataset('tips')
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sbn.relplot(x='total_bill',y='tip',data=tip,col='time',hue='day',kind='line')

# %%
sbn.catplot(x='day',y='total_bill',kind='box',data=tip)

# %%
sbn.regplot(x='total_bill',y='tip',data=tip)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
pip install sklearn
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2936 sha256=b6e86cb7b9423cfb4b59282a7918f79413ea3a6699b643dc1d0443041a02573d
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\c5\88\35\cc8a1e198b27a1d3d9d3f9b30090b9d5531778847835472ec4
# Successfully built sklearn
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import sklearn
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.preprocessing import Normalizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 from sklearn.preprocessing import Normalizer
#
# ModuleNotFoundError: No module named 'sklearn'
